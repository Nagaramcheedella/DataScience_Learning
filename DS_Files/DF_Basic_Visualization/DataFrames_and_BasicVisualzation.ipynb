# %% [markdown]
#                                           DataFrame Basic Examples

# %%
# Uploaded DemographicData.csv file. File may delete after session completed. Make sure to re upload same file in new session

# %%
# We majorly use numpy,pandas,matplotlib.pyplot and seaborn packages for EDA(Exploratory Data Analysis)

# %% [markdown]
#  DataFrmae: A DataFrame is a data structure that organizes data into a 2-dimensional table of rows and columns, much like a spreadsheet

# %%
# Importing requirerd packages

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Read csv file using pandas.read_csv

# %%
stats = pd.read_csv("/content/DemographicData.csv")

# %%
# Get/See loaded data

stats
# Out:
#              Country Name Country Code  Birth rate  Internet users  \
# 0                   Aruba          ABW      10.244            78.9
# 1             Afghanistan          AFG      35.253             5.9
# 2                  Angola          AGO      45.985            19.1
# 3                 Albania          ALB      12.877            57.2
# 4    United Arab Emirates          ARE      11.044            88.0
# ..                    ...          ...         ...             ...
# 190           Yemen, Rep.          YEM      32.947            20.0
# 191          South Africa          ZAF      20.850            46.5
# 192      Congo, Dem. Rep.          COD      42.394             2.2
# 193                Zambia          ZMB      40.471            15.4
# 194              Zimbabwe          ZWE      35.715            18.5
#
#             Income Group
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ...

# %%
# No of rows

len(stats)
# Out:
# 195

# %%
# Get list of columns in loaded csv file

stats.columns
# Out:
# Index(['Country Name', 'Country Code', 'Birth rate', 'Internet users',
#        'Income Group'],
#       dtype='object')

# %%
len(stats.columns)
# Out:
# 5

# %%
# To get Top N Rows
# By default it will be 5
stats.head()
# Out:
#            Country Name Country Code  Birth rate  Internet users  \
# 0                 Aruba          ABW      10.244            78.9
# 1           Afghanistan          AFG      35.253             5.9
# 2                Angola          AGO      45.985            19.1
# 3               Albania          ALB      12.877            57.2
# 4  United Arab Emirates          ARE      11.044            88.0
#
#           Income Group
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
stats.head(12)
# Out:
#             Country Name Country Code  Birth rate  Internet users  \
# 0                  Aruba          ABW      10.244         78.9000
# 1            Afghanistan          AFG      35.253          5.9000
# 2                 Angola          AGO      45.985         19.1000
# 3                Albania          ALB      12.877         57.2000
# 4   United Arab Emirates          ARE      11.044         88.0000
# 5              Argentina          ARG      17.716         59.9000
# 6                Armenia          ARM      13.308         41.9000
# 7    Antigua and Barbuda          ATG      16.447         63.4000
# 8              Australia          AUS      13.200         83.0000
# 9                Austria          AUT       9.400         80.6188
# 10            Azerbaijan          AZE      18.300         58.7000
# 11               Burundi          BDI      44.151          1.3000
#
#            Income Group
# 0           High income
# 1            Low income
# 2   Upper middle income
# ...

# %%
# To get bottom Rows we use tail
# By default it will be 5

stats.tail(10)
# Out:
#               Country Name Country Code  Birth rate  Internet users  \
# 185  Virgin Islands (U.S.)          VIR      10.700            45.3
# 186                Vietnam          VNM      15.537            43.9
# 187                Vanuatu          VUT      26.739            11.3
# 188     West Bank and Gaza          PSE      30.394            46.6
# 189                  Samoa          WSM      26.172            15.3
# 190            Yemen, Rep.          YEM      32.947            20.0
# 191           South Africa          ZAF      20.850            46.5
# 192       Congo, Dem. Rep.          COD      42.394             2.2
# 193                 Zambia          ZMB      40.471            15.4
# 194               Zimbabwe          ZWE      35.715            18.5
#
#             Income Group
# 185          High income
# 186  Lower middle income
# 187  Lower middle income
# 188  Lower middle income
# 189  Lower middle income
# 190  Lower middle income
# 191  Upper middle income
# ...

# %%
stats.tail()
# Out:
#          Country Name Country Code  Birth rate  Internet users  \
# 190       Yemen, Rep.          YEM      32.947            20.0
# 191      South Africa          ZAF      20.850            46.5
# 192  Congo, Dem. Rep.          COD      42.394             2.2
# 193            Zambia          ZMB      40.471            15.4
# 194          Zimbabwe          ZWE      35.715            18.5
#
#             Income Group
# 190  Lower middle income
# 191  Upper middle income
# 192           Low income
# 193  Lower middle income
# 194           Low income

# %%
# To get information on Columns we use info()

stats.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country Name    195 non-null    object
#  1   Country Code    195 non-null    object
#  2   Birth rate      195 non-null    float64
#  3   Internet users  195 non-null    float64
#  4   Income Group    195 non-null    object
# dtypes: float64(2), object(3)
# memory usage: 7.7+ KB

# %%
# To get statistics of dataframe we use describe
# It will perform statistics on Numerical Columns.
# In below table std: standard deviation
stats.describe()
# Out:
#        Birth rate  Internet users
# count  195.000000      195.000000
# mean    21.469928       42.076471
# std     10.605467       29.030788
# min      7.900000        0.900000
# 25%     12.120500       14.520000
# 50%     19.680000       41.000000
# 75%     29.759500       66.225000
# max     49.661000       96.546800

# %%
# We can do transpose of tables

stats.describe().transpose()
# Out:
#                 count       mean        std  min      25%    50%      75%  \
# Birth rate      195.0  21.469928  10.605467  7.9  12.1205  19.68  29.7595
# Internet users  195.0  42.076471  29.030788  0.9  14.5200  41.00  66.2250
#
#                     max
# Birth rate      49.6610
# Internet users  96.5468

# %%
# We can change Column Names

stats.columns = ['CountryName', 'CountryCode', 'BirthRate', 'InternetUsers', 'IncomeGroup']

# %%
stats
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 0                   Aruba         ABW     10.244           78.9
# 1             Afghanistan         AFG     35.253            5.9
# 2                  Angola         AGO     45.985           19.1
# 3                 Albania         ALB     12.877           57.2
# 4    United Arab Emirates         ARE     11.044           88.0
# ..                    ...         ...        ...            ...
# 190           Yemen, Rep.         YEM     32.947           20.0
# 191          South Africa         ZAF     20.850           46.5
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 193                Zambia         ZMB     40.471           15.4
# 194              Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ..                   ...
# ...

# %%
# We can change particular Column Name
# <df>.columns.str.replace(oldName, newName)

stats.columns = stats.columns.str.replace("InternetUsers", "internetusers")

# %%
stats.head()
# Out:
#             CountryName CountryCode  BirthRate  internetusers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
stats.columns = stats.columns.str.replace( "internetusers", "InternetUsers")

# %%
stats.head()
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
# To get specific rows

stats[2:4]
# Out:
#   CountryName CountryCode  BirthRate  InternetUsers          IncomeGroup
# 2      Angola         AGO     45.985           19.1  Upper middle income
# 3     Albania         ALB     12.877           57.2  Upper middle income

# %%
# To get Specific Columns Names

stats.columns[2:4]
# Out:
# Index(['BirthRate', 'InternetUsers'], dtype='object')

# %%
# To get head(N number of rows) for particular co;umn
stats.CountryCode.head()
# Out:
# 0    ABW
# 1    AFG
# 2    AGO
# 3    ALB
# 4    ARE
# Name: CountryCode, dtype: object

# %%
# Subsetting Rows and Columns. i.e; to get particular rows of particular columns

stats[2:8][["CountryCode", "InternetUsers"]]
# Out:
#   CountryCode  InternetUsers
# 2         AGO           19.1
# 3         ALB           57.2
# 4         ARE           88.0
# 5         ARG           59.9
# 6         ARM           41.9
# 7         ATG           63.4

# %%
# get data from beginning to 10

stats[:10]
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244        78.9000
# 1           Afghanistan         AFG     35.253         5.9000
# 2                Angola         AGO     45.985        19.1000
# 3               Albania         ALB     12.877        57.2000
# 4  United Arab Emirates         ARE     11.044        88.0000
# 5             Argentina         ARG     17.716        59.9000
# 6               Armenia         ARM     13.308        41.9000
# 7   Antigua and Barbuda         ATG     16.447        63.4000
# 8             Australia         AUS     13.200        83.0000
# 9               Austria         AUT      9.400        80.6188
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income
# 5          High income
# 6  Lower middle income
# 7          High income
# 8          High income
# 9          High income

# %%
# to get from 185 to end of table

stats[185:]
# Out:
#                CountryName CountryCode  BirthRate  InternetUsers  \
# 185  Virgin Islands (U.S.)         VIR     10.700           45.3
# 186                Vietnam         VNM     15.537           43.9
# 187                Vanuatu         VUT     26.739           11.3
# 188     West Bank and Gaza         PSE     30.394           46.6
# 189                  Samoa         WSM     26.172           15.3
# 190            Yemen, Rep.         YEM     32.947           20.0
# 191           South Africa         ZAF     20.850           46.5
# 192       Congo, Dem. Rep.         COD     42.394            2.2
# 193                 Zambia         ZMB     40.471           15.4
# 194               Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 185          High income
# 186  Lower middle income
# 187  Lower middle income
# 188  Lower middle income
# 189  Lower middle income
# 190  Lower middle income
# 191  Upper middle income
# 192           Low income
# ...

# %%
# To get data with particular interval

stats[1:10:2]
# Out:
#            CountryName CountryCode  BirthRate  InternetUsers  \
# 1          Afghanistan         AFG     35.253         5.9000
# 3              Albania         ALB     12.877        57.2000
# 5            Argentina         ARG     17.716        59.9000
# 7  Antigua and Barbuda         ATG     16.447        63.4000
# 9              Austria         AUT      9.400        80.6188
#
#            IncomeGroup
# 1           Low income
# 3  Upper middle income
# 5          High income
# 7          High income
# 9          High income

# %%
# We can create a New Column and provide custom values.

stats['NewColumn'] = stats.InternetUsers/stats.BirthRate  # some random caluculation to load in NewColumn

# %%
stats
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 0                   Aruba         ABW     10.244           78.9
# 1             Afghanistan         AFG     35.253            5.9
# 2                  Angola         AGO     45.985           19.1
# 3                 Albania         ALB     12.877           57.2
# 4    United Arab Emirates         ARE     11.044           88.0
# ..                    ...         ...        ...            ...
# 190           Yemen, Rep.         YEM     32.947           20.0
# 191          South Africa         ZAF     20.850           46.5
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 193                Zambia         ZMB     40.471           15.4
# 194              Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup  NewColumn
# 0            High income   7.702070
# 1             Low income   0.167362
# 2    Upper middle income   0.415353
# 3    Upper middle income   4.442028
# ...

# %%
stats.NewColumn
# Out:
# 0      7.702070
# 1      0.167362
# 2      0.415353
# 3      4.442028
# 4      7.968127
#          ...
# 190    0.607036
# 191    2.230216
# 192    0.051894
# 193    0.380519
# 194    0.517990
# Name: NewColumn, Length: 195, dtype: float64

# %%
stats.newcol = 2

# %%
stats.newcol
# Out:
# 2

# %%
# We can drop particular column
# in pandas drop, second argument is axis. Which is 0 for Row and 1 for Column

newstats = stats.drop("NewColumn", 1)
# Out:
# <ipython-input-35-e8f226048dd1>:4: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   newstats = stats.drop("NewColumn", 1)

# %%
stats
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 0                   Aruba         ABW     10.244           78.9
# 1             Afghanistan         AFG     35.253            5.9
# 2                  Angola         AGO     45.985           19.1
# 3                 Albania         ALB     12.877           57.2
# 4    United Arab Emirates         ARE     11.044           88.0
# ..                    ...         ...        ...            ...
# 190           Yemen, Rep.         YEM     32.947           20.0
# 191          South Africa         ZAF     20.850           46.5
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 193                Zambia         ZMB     40.471           15.4
# 194              Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup  NewColumn
# 0            High income   7.702070
# 1             Low income   0.167362
# 2    Upper middle income   0.415353
# 3    Upper middle income   4.442028
# ...

# %%
newstats
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 0                   Aruba         ABW     10.244           78.9
# 1             Afghanistan         AFG     35.253            5.9
# 2                  Angola         AGO     45.985           19.1
# 3                 Albania         ALB     12.877           57.2
# 4    United Arab Emirates         ARE     11.044           88.0
# ..                    ...         ...        ...            ...
# 190           Yemen, Rep.         YEM     32.947           20.0
# 191          South Africa         ZAF     20.850           46.5
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 193                Zambia         ZMB     40.471           15.4
# 194              Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ..                   ...
# ...

# %%
# To remove drop a Row . 
# Here removing 194th Row
newstats.drop(194,0)
# Out:
# <ipython-input-38-ad3b3f35d8af>:3: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   newstats.drop(194,0)
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 0                   Aruba         ABW     10.244           78.9
# 1             Afghanistan         AFG     35.253            5.9
# 2                  Angola         AGO     45.985           19.1
# 3                 Albania         ALB     12.877           57.2
# 4    United Arab Emirates         ARE     11.044           88.0
# ..                    ...         ...        ...            ...
# 189                 Samoa         WSM     26.172           15.3
# 190           Yemen, Rep.         YEM     32.947           20.0
# 191          South Africa         ZAF     20.850           46.5
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 193                Zambia         ZMB     40.471           15.4
#
# ...

# %%
# We can do Conditional Filters as well 

# df[(condition1) & or | (condition2) etc.....]

stats[(stats.InternetUsers < 2) & (stats.BirthRate > 40)]
# Out:
#     CountryName CountryCode  BirthRate  InternetUsers IncomeGroup  NewColumn
# 11      Burundi         BDI     44.151            1.3  Low income   0.029444
# 127       Niger         NER     49.661            1.7  Low income   0.034232
# 156     Somalia         SOM     43.891            1.5  Low income   0.034176

# %%
stats[(stats.InternetUsers < 2) | (stats.BirthRate > 40)]
# Out:
#           CountryName CountryCode  BirthRate  InternetUsers  \
# 2              Angola         AGO     45.985           19.1
# 11            Burundi         BDI     44.151            1.3
# 14       Burkina Faso         BFA     40.551            9.1
# 52            Eritrea         ERI     34.800            0.9
# 55           Ethiopia         ETH     32.925            1.9
# 64             Guinea         GIN     37.337            1.6
# 65        Gambia, The         GMB     42.525           14.0
# 115              Mali         MLI     44.138            3.5
# 117           Myanmar         MMR     18.119            1.6
# 127             Niger         NER     49.661            1.7
# 128           Nigeria         NGA     40.045           38.0
# 154      Sierra Leone         SLE     36.729            1.7
# 156           Somalia         SOM     43.891            1.5
# 167              Chad         TCD     45.745            2.3
# 172       Timor-Leste         TLS     35.755            1.1
# ...

# %%
stats[((stats.InternetUsers < 2) | (stats.BirthRate > 40)) & (stats.IncomeGroup == 'Low income')]
# Out:
#           CountryName CountryCode  BirthRate  InternetUsers IncomeGroup  \
# 11            Burundi         BDI     44.151            1.3  Low income
# 14       Burkina Faso         BFA     40.551            9.1  Low income
# 52            Eritrea         ERI     34.800            0.9  Low income
# 55           Ethiopia         ETH     32.925            1.9  Low income
# 64             Guinea         GIN     37.337            1.6  Low income
# 65        Gambia, The         GMB     42.525           14.0  Low income
# 115              Mali         MLI     44.138            3.5  Low income
# 127             Niger         NER     49.661            1.7  Low income
# 154      Sierra Leone         SLE     36.729            1.7  Low income
# 156           Somalia         SOM     43.891            1.5  Low income
# 167              Chad         TCD     45.745            2.3  Low income
# 178            Uganda         UGA     43.474           16.2  Low income
# ...

# %%
stats[(stats['InternetUsers'] < 2) & (stats['BirthRate'] > 40)]
# Out:
#     CountryName CountryCode  BirthRate  InternetUsers IncomeGroup  NewColumn
# 11      Burundi         BDI     44.151            1.3  Low income   0.029444
# 127       Niger         NER     49.661            1.7  Low income   0.034232
# 156     Somalia         SOM     43.891            1.5  Low income   0.034176

# %%
# To get Unique categories in a column, we use unique
# df.<colname>.unique()

stats.IncomeGroup.unique()
# Out:
# array(['High income', 'Low income', 'Upper middle income',
#        'Lower middle income'], dtype=object)

# %% [markdown]
#                                                      ***VISUALZATION using Different Plots***
#
# ---

# %%
# We can Visulaize the data in form of Graphs using seaborn library which we already imported as sns
# Distrubtion Plot or Histogram Plot
# sns.distplot(<datafrmae[colName]>)

visual1 = sns.distplot(stats['InternetUsers'])
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# Same we can get using displot()

visual1 = sns.displot(stats['InternetUsers'])

# %%
visual1 = sns.displot(data=stats['InternetUsers'], bins = 40)

# %%
visual1 = sns.distplot(stats['InternetUsers'], bins = 40)
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# Box Plot
# x, y : strings, optional: Input variables; these should be column names in data.
# data : DataFrame: Tidy ("long-form") dataframe where each column is a variable and each row is an observation.
# sns.boxplot(data = <df>, x = <colName for x axis>, y = <colName for y axis>)

visualbox1 = sns.boxplot(data = stats, x=stats.IncomeGroup, y=stats.BirthRate)

# %%
# Another way

visualbox1 = sns.boxplot(data = stats, x="IncomeGroup", y="BirthRate")

# %%
# Linear Plot
# x, y : strings, optional: Input variables; these should be column names in data.
# fit_reg : bool, optional : If True, estimate and plot a regression model relating the x and y variables.
# data : DataFrame: Tidy ("long-form") dataframe where each column is a variable and each row is an observation.
# hue: In seaborn, the hue parameter determines which column in the data frame should be used for colour encoding.

visulalinear = sns.lmplot(data = stats, x = "InternetUsers", y="BirthRate", fit_reg = False, hue = "IncomeGroup")

# %%
visulalinear = sns.lmplot(data = stats, x = "InternetUsers", y="BirthRate", fit_reg = True, hue = "IncomeGroup")

# %%
# Line Plot
# x, y : strings, optional: Input variables; these should be column names in data.
# data : DataFrame: Tidy ("long-form") dataframe where each column is a variable and each row is an observation.


visualline = sns.lineplot(data = stats, x = "InternetUsers", y="BirthRate")

# %%
# .at() and .iat()
